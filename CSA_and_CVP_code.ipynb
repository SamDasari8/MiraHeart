# %% [markdown]
# <a href="https://colab.research.google.com/github/SamDasari8/MiraHeart/blob/main/CSA_and_CVP_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas._libs.lib import indices_fast
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import csv
from math import e
from numpy import asarray
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import seaborn as sns
from numpy.lib.stride_tricks import sliding_window_view
from sklearn.linear_model import LogisticRegression

url = "https://raw.githubusercontent.com/SamDasari8/MiraHeart/main/CSA%3ACSV%20data.csv"
dat = pd.read_csv(url)
z = dat['Time_42']
x = dat['CSA_42']
x = np.array(x).reshape(-1,1)
y = dat ['CVP_42']
y = np.array(y).reshape(-1,1)
model = LinearRegression().fit(x, y)
r_squared = model.score(x, y)
print(r_squared)
plt.plot(x,y)
#print(y)
#print(x)
#print(z)
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = .25, train_size=.75)
#print(x_train)
#print(x_test)
#print(y_train)
#print(y_test)
model = LinearRegression().fit(x_train, y_train)
r_squared2 = model.score(x_train, y_train)
print(r_squared2)
plt.figure()
plt.plot(x_train,y_train)
#pred = model.predict(x_test)
#sqe = mean_squared_error(y_test,pred)
#sqrtsqe = np.sqrt(sqe)
#print(sqe)
# Out:
# 0.022426937565313443
# 0.016297695099029785
